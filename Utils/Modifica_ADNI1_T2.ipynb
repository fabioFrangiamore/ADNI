# %%
import pandas as pd
import os
import SimpleITK as sitk
import matplotlib.pyplot as plt

# %%
ADNI1_T2_img = 'D:\ADNI\Dati\ADNI1_T2'

# %%
dir_subj_ADNI2 = os.listdir(ADNI1_T2_img)

# %%
for subject in dir_subj_ADNI2:
    for root, dirs, files in os.walk(ADNI1_T2_img + '/' +  subject):
        sub = (subject)
        print(dirs)
        img = (files)
        print(files)
# Out:
# ['Axial_PD_T2_FSE']
# []
# ['2006-04-18_08_38_08.0', '2006-04-18_08_46_25.0']
# []
# ['S13404']
# []
# []
# ['ADNI_002_S_0295_MR_Axial_PD_T2_FSE__br_raw_20060418201017471_2_S13404_I13723.nii']
# ['S13405']
# []
# []
# ['ADNI_002_S_0295_MR_Axial_PD_T2_FSE__br_raw_20060418201717292_2_S13405_I13724.nii']
# ['Axial_PD_T2_FSE', 'Double_TSE']
# []
# ['2006-05-02_12_49_40.0']
# []
# ['S13892']
# []
# []
# ['ADNI_002_S_0413_MR_Axial_PD_T2_FSE__br_raw_20060502144219726_2_S13892_I14439.nii']
# ['2006-05-19_16_40_10.0']
# []
# ['S14780']
# []
# []
# ['ADNI_002_S_0413_MR____________Double_TSE__br_raw_20060519181031066_2_S14780_I15804.nii']
# ['Axial_PD_T2_FSE', 'Double_TSE']
# []
# ['2006-05-23_15_19_35.0']
# []
# ['S14874']
# []
# []
# ['ADNI_002_S_0559_MR_Axial_PD_T2_FSE__br_raw_20060524075201874_2_S14874_I15950.nii']
# ['2006-06-27_18_50_57.0', '2006-06-27_19_00_56.0']
# []
# ['S15972']
# []
# []
# ['ADNI_002_S_0559_MR____________Double_TSE__br_raw_20060629161136485_2_S15972_I17692.nii']
# ...

# %%
print(img[0], sub)
# Out:
# ADNI_941_S_1363_MR_Axial_PD-T2_TSE__br_raw_20070313130340470_86_S28007_I44493.nii 941_S_1363

# %%
img1 = sitk.ReadImage('D:\ADNI\Dati\ADNI1_T2\941_S_1363\Axial_PD-T2_TSE/2007-03-12_13_02_27.0\S28007/' + img[0])
T2 = sitk.GetArrayFromImage(img1)

# %%
plt.imshow(T2[30,: , :], cmap='gray')

# %%
import nipype
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-46-1c5d8be96d21> in <module>
# ----> 1 import nipype
#
# ModuleNotFoundError: No module named 'nipype'
